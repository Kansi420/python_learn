# %% [markdown]
# # Pandas
# Links
# - https://drive.google.com/file/d/1Ly_e3BJro5tdEcUzQzrFG7SujSR0DXBT/view
# - https://pandas.pydata.org/Pandas_Cheat_Sheet.pdf

# %%
import pandas as pd

# %% [markdown]
# ### Read CSV

# %%
df = pd.read_csv('Popular_Baby_Names.csv')
df
# Out:
#        Year of Birth  Gender           Ethnicity Child's First Name  Count  \
# 0               2011  FEMALE            HISPANIC          GERALDINE     13
# 1               2011  FEMALE            HISPANIC                GIA     21
# 2               2011  FEMALE            HISPANIC             GIANNA     49
# 3               2011  FEMALE            HISPANIC            GISELLE     38
# 4               2011  FEMALE            HISPANIC              GRACE     36
# ...              ...     ...                 ...                ...    ...
# 57577           2014    MALE  WHITE NON HISPANIC             Yousef     18
# 57578           2014    MALE  WHITE NON HISPANIC            Youssef     24
# 57579           2014    MALE  WHITE NON HISPANIC              Yusuf     16
# 57580           2014    MALE  WHITE NON HISPANIC            Zachary     90
# 57581           2014    MALE  WHITE NON HISPANIC                Zev     49
#
#        Rank
# 0        75
# 1        67
# 2        42
# 3        51
# 4        53
# ...     ...
# 57577    94
# 57578    88
# 57579    96
# 57580    39
# 57581    65
#
# [57582 rows x 6 columns]

# %%
df.describe()
# Out:
#        Year of Birth         Count          Rank
# count   57582.000000  57582.000000  57582.000000
# mean     2013.283352     33.929596     57.066114
# std         2.056076     39.027451     25.519447
# min      2011.000000     10.000000      1.000000
# 25%      2012.000000     13.000000     38.000000
# 50%      2013.000000     20.000000     59.000000
# 75%      2014.000000     36.000000     78.000000
# max      2019.000000    426.000000    102.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 57582 entries, 0 to 57581
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Year of Birth       57582 non-null  int64
#  1   Gender              57582 non-null  object
#  2   Ethnicity           57582 non-null  object
#  3   Child's First Name  57582 non-null  object
#  4   Count               57582 non-null  int64
#  5   Rank                57582 non-null  int64
# dtypes: int64(3), object(3)
# memory usage: 2.6+ MB

# %%
df.plot()
# Out:
# <Axes: >

# %%
df.iloc()[0]
# Out:
# Year of Birth              2011
# Gender                   FEMALE
# Ethnicity              HISPANIC
# Child's First Name    GERALDINE
# Count                        13
# Rank                         75
# Name: 0, dtype: object

# %%
df.iloc[:2]
# Out:
#    Year of Birth  Gender Ethnicity Child's First Name  Count  Rank
# 0           2011  FEMALE  HISPANIC          GERALDINE     13    75
# 1           2011  FEMALE  HISPANIC                GIA     21    67

# %%
df.iloc[:, 0]
# Out:
# 0        2011
# 1        2011
# 2        2011
# 3        2011
# 4        2011
#          ...
# 57577    2014
# 57578    2014
# 57579    2014
# 57580    2014
# 57581    2014
# Name: Year of Birth, Length: 57582, dtype: int64

# %%
df.iloc()[:, :2]
# Out:
#        Year of Birth  Gender
# 0               2011  FEMALE
# 1               2011  FEMALE
# 2               2011  FEMALE
# 3               2011  FEMALE
# 4               2011  FEMALE
# ...              ...     ...
# 57577           2014    MALE
# 57578           2014    MALE
# 57579           2014    MALE
# 57580           2014    MALE
# 57581           2014    MALE
#
# [57582 rows x 2 columns]

# %%
df.iloc()[1, 1]
# Out:
# 'FEMALE'

# %%
df.loc()[:, 'Gender']
# Out:
# 0        FEMALE
# 1        FEMALE
# 2        FEMALE
# 3        FEMALE
# 4        FEMALE
#           ...
# 57577      MALE
# 57578      MALE
# 57579      MALE
# 57580      MALE
# 57581      MALE
# Name: Gender, Length: 57582, dtype: object

# %%
df.loc[:, ['Year of Birth', 'Gender']]
# Out:
#        Year of Birth  Gender
# 0               2011  FEMALE
# 1               2011  FEMALE
# 2               2011  FEMALE
# 3               2011  FEMALE
# 4               2011  FEMALE
# ...              ...     ...
# 57577           2014    MALE
# 57578           2014    MALE
# 57579           2014    MALE
# 57580           2014    MALE
# 57581           2014    MALE
#
# [57582 rows x 2 columns]

# %%
df.assign()
# Out:
#        Year of Birth  Gender           Ethnicity Child's First Name  Count  \
# 0               2011  FEMALE            HISPANIC          GERALDINE     13
# 1               2011  FEMALE            HISPANIC                GIA     21
# 2               2011  FEMALE            HISPANIC             GIANNA     49
# 3               2011  FEMALE            HISPANIC            GISELLE     38
# 4               2011  FEMALE            HISPANIC              GRACE     36
# ...              ...     ...                 ...                ...    ...
# 57577           2014    MALE  WHITE NON HISPANIC             Yousef     18
# 57578           2014    MALE  WHITE NON HISPANIC            Youssef     24
# 57579           2014    MALE  WHITE NON HISPANIC              Yusuf     16
# 57580           2014    MALE  WHITE NON HISPANIC            Zachary     90
# 57581           2014    MALE  WHITE NON HISPANIC                Zev     49
#
#        Rank
# 0        75
# 1        67
# 2        42
# 3        51
# 4        53
# ...     ...
# 57577    94
# 57578    88
# 57579    96
# 57580    39
# 57581    65
#
# [57582 rows x 6 columns]

# %%
df.query('Count > 40 and Rank < 20')
# Out:
#        Year of Birth  Gender           Ethnicity Child's First Name  Count  \
# 6               2011  FEMALE            HISPANIC             HAILEY    126
# 22              2011  FEMALE            HISPANIC           ISABELLA    331
# 81              2011  FEMALE            HISPANIC           KIMBERLY    103
# 90              2011  FEMALE            HISPANIC               LEAH    123
# 109             2011  FEMALE            HISPANIC            MADISON    122
# ...              ...     ...                 ...                ...    ...
# 57457           2014    MALE  WHITE NON HISPANIC            Michael    268
# 57468           2014    MALE  WHITE NON HISPANIC              Moshe    267
# 57475           2014    MALE  WHITE NON HISPANIC           Nicholas    166
# 57517           2014    MALE  WHITE NON HISPANIC             Samuel    206
# 57557           2014    MALE  WHITE NON HISPANIC            William    183
#
#        Rank
# 6         8
# 22        1
# 81       13
# 90        9
# 109      10
# ...     ...
# 57457     3
# 57468     4
# 57475    16
# 57517     9
# 57557    13
#
# [4435 rows x 6 columns]

# %%
df.sort_values(by='Count')
# Out:
#        Year of Birth  Gender           Ethnicity Child's First Name  Count  \
# 12696           2012    MALE      BLACK NON HISP              KEITH     10
# 50836           2011    MALE  BLACK NON HISPANIC             QUINCY     10
# 3994            2012  FEMALE      ASIAN AND PACI            BRIANNA     10
# 15541           2011  FEMALE            HISPANIC            SAVANNA     10
# 20835           2013    MALE  WHITE NON HISPANIC             Shraga     10
# ...              ...     ...                 ...                ...    ...
# 26907           2011    MALE            HISPANIC             JAYDEN    426
# 17403           2011    MALE            HISPANIC             JAYDEN    426
# 40996           2011    MALE            HISPANIC             JAYDEN    426
# 51013           2011    MALE            HISPANIC             JAYDEN    426
# 3447            2011    MALE            HISPANIC             JAYDEN    426
#
#        Rank
# 12696    61
# 50836    64
# 3994     45
# 15541    78
# 20835   100
# ...     ...
# 26907     1
# 17403     1
# 40996     1
# 51013     1
# 3447      1
#
# [57582 rows x 6 columns]

# %%
df.sort_values(by='Rank', ascending=False)
# Out:
#        Year of Birth  Gender           Ethnicity Child's First Name  Count  \
# 15137           2014    MALE  WHITE NON HISPANIC           Giuseppe     10
# 15158           2014    MALE  WHITE NON HISPANIC              Imran     10
# 15120           2014    MALE  WHITE NON HISPANIC               Erik     10
# 23260           2014    MALE  WHITE NON HISPANIC           Giuseppe     10
# 15147           2014    MALE  WHITE NON HISPANIC             Hayden     10
# ...              ...     ...                 ...                ...    ...
# 50762           2011    MALE  BLACK NON HISPANIC             JAYDEN    184
# 54743           2013    MALE  BLACK NON HISPANIC              Ethan    146
# 16870           2012  FEMALE      ASIAN AND PACI              CHLOE    172
# 52240           2012  FEMALE      WHITE NON HISP               EMMA    228
# 28715           2012    MALE      BLACK NON HISP             JAYDEN    171
#
#        Rank
# 15137   102
# 15158   102
# 15120   102
# 23260   102
# 15147   102
# ...     ...
# 50762     1
# 54743     1
# 16870     1
# 52240     1
# 28715     1
#
# [57582 rows x 6 columns]

# %%
df.sort_values(by=['Count', 'Rank']) #first sort by count then by rank
# Out:
#        Year of Birth  Gender           Ethnicity Child's First Name  Count  \
# 39473           2019  FEMALE  BLACK NON HISPANIC              Amani     10
# 39474           2019  FEMALE  BLACK NON HISPANIC             Ariyah     10
# 39475           2019  FEMALE  BLACK NON HISPANIC               Eden     10
# 39476           2019  FEMALE  BLACK NON HISPANIC                Gia     10
# 39477           2019  FEMALE  BLACK NON HISPANIC               Hawa     10
# ...              ...     ...                 ...                ...    ...
# 3447            2011    MALE            HISPANIC             JAYDEN    426
# 17403           2011    MALE            HISPANIC             JAYDEN    426
# 26907           2011    MALE            HISPANIC             JAYDEN    426
# 40996           2011    MALE            HISPANIC             JAYDEN    426
# 51013           2011    MALE            HISPANIC             JAYDEN    426
#
#        Rank
# 39473    34
# 39474    34
# 39475    34
# 39476    34
# 39477    34
# ...     ...
# 3447      1
# 17403     1
# 26907     1
# 40996     1
# 51013     1
#
# [57582 rows x 6 columns]

# %%
df.sample(n=2, replace=False, random_state=3)
# Out:
#        Year of Birth Gender                   Ethnicity Child's First Name  \
# 39570           2011   MALE  ASIAN AND PACIFIC ISLANDER             AUSTIN
# 24953           2017   MALE                    HISPANIC            Vincent
#
#        Count  Rank
# 39570     64    16
# 24953     19    80

# %%
df.sample(n=2, replace=False, random_state=3, axis=1)
# Out:
#       Child's First Name  Rank
# 0              GERALDINE    75
# 1                    GIA    67
# 2                 GIANNA    42
# 3                GISELLE    51
# 4                  GRACE    53
# ...                  ...   ...
# 57577             Yousef    94
# 57578            Youssef    88
# 57579              Yusuf    96
# 57580            Zachary    39
# 57581                Zev    65
#
# [57582 rows x 2 columns]

# %%
df.isnull()
# Out:
#        Year of Birth  Gender  Ethnicity  Child's First Name  Count   Rank
# 0              False   False      False               False  False  False
# 1              False   False      False               False  False  False
# 2              False   False      False               False  False  False
# 3              False   False      False               False  False  False
# 4              False   False      False               False  False  False
# ...              ...     ...        ...                 ...    ...    ...
# 57577          False   False      False               False  False  False
# 57578          False   False      False               False  False  False
# 57579          False   False      False               False  False  False
# 57580          False   False      False               False  False  False
# 57581          False   False      False               False  False  False
#
# [57582 rows x 6 columns]

# %%
df.fillna(0) #fills missing null values with 0
# Out:
#        Year of Birth  Gender           Ethnicity Child's First Name  Count  \
# 0               2011  FEMALE            HISPANIC          GERALDINE     13
# 1               2011  FEMALE            HISPANIC                GIA     21
# 2               2011  FEMALE            HISPANIC             GIANNA     49
# 3               2011  FEMALE            HISPANIC            GISELLE     38
# 4               2011  FEMALE            HISPANIC              GRACE     36
# ...              ...     ...                 ...                ...    ...
# 57577           2014    MALE  WHITE NON HISPANIC             Yousef     18
# 57578           2014    MALE  WHITE NON HISPANIC            Youssef     24
# 57579           2014    MALE  WHITE NON HISPANIC              Yusuf     16
# 57580           2014    MALE  WHITE NON HISPANIC            Zachary     90
# 57581           2014    MALE  WHITE NON HISPANIC                Zev     49
#
#        Rank
# 0        75
# 1        67
# 2        42
# 3        51
# 4        53
# ...     ...
# 57577    94
# 57578    88
# 57579    96
# 57580    39
# 57581    65
#
# [57582 rows x 6 columns]

# %%
# forward-fill missing values (propagates last valid observation forward to next)
df.fillna(method='ffill')
# Out:
#        Year of Birth  Gender           Ethnicity Child's First Name  Count  \
# 0               2011  FEMALE            HISPANIC          GERALDINE     13
# 1               2011  FEMALE            HISPANIC                GIA     21
# 2               2011  FEMALE            HISPANIC             GIANNA     49
# 3               2011  FEMALE            HISPANIC            GISELLE     38
# 4               2011  FEMALE            HISPANIC              GRACE     36
# ...              ...     ...                 ...                ...    ...
# 57577           2014    MALE  WHITE NON HISPANIC             Yousef     18
# 57578           2014    MALE  WHITE NON HISPANIC            Youssef     24
# 57579           2014    MALE  WHITE NON HISPANIC              Yusuf     16
# 57580           2014    MALE  WHITE NON HISPANIC            Zachary     90
# 57581           2014    MALE  WHITE NON HISPANIC                Zev     49
#
#        Rank
# 0        75
# 1        67
# 2        42
# 3        51
# 4        53
# ...     ...
# 57577    94
# 57578    88
# 57579    96
# 57580    39
# 57581    65
#
# [57582 rows x 6 columns]

# %%
# backward-fill missing values (propagates next valid observation backward to last)
df.fillna(method='bfill')
# Out:
#        Year of Birth  Gender           Ethnicity Child's First Name  Count  \
# 0               2011  FEMALE            HISPANIC          GERALDINE     13
# 1               2011  FEMALE            HISPANIC                GIA     21
# 2               2011  FEMALE            HISPANIC             GIANNA     49
# 3               2011  FEMALE            HISPANIC            GISELLE     38
# 4               2011  FEMALE            HISPANIC              GRACE     36
# ...              ...     ...                 ...                ...    ...
# 57577           2014    MALE  WHITE NON HISPANIC             Yousef     18
# 57578           2014    MALE  WHITE NON HISPANIC            Youssef     24
# 57579           2014    MALE  WHITE NON HISPANIC              Yusuf     16
# 57580           2014    MALE  WHITE NON HISPANIC            Zachary     90
# 57581           2014    MALE  WHITE NON HISPANIC                Zev     49
#
#        Rank
# 0        75
# 1        67
# 2        42
# 3        51
# 4        53
# ...     ...
# 57577    94
# 57578    88
# 57579    96
# 57580    39
# 57581    65
#
# [57582 rows x 6 columns]

# %%
# fill missing values using interpolation
df.interpolate()
# Out:
#        Year of Birth  Gender           Ethnicity Child's First Name  Count  \
# 0               2011  FEMALE            HISPANIC          GERALDINE     13
# 1               2011  FEMALE            HISPANIC                GIA     21
# 2               2011  FEMALE            HISPANIC             GIANNA     49
# 3               2011  FEMALE            HISPANIC            GISELLE     38
# 4               2011  FEMALE            HISPANIC              GRACE     36
# ...              ...     ...                 ...                ...    ...
# 57577           2014    MALE  WHITE NON HISPANIC             Yousef     18
# 57578           2014    MALE  WHITE NON HISPANIC            Youssef     24
# 57579           2014    MALE  WHITE NON HISPANIC              Yusuf     16
# 57580           2014    MALE  WHITE NON HISPANIC            Zachary     90
# 57581           2014    MALE  WHITE NON HISPANIC                Zev     49
#
#        Rank
# 0        75
# 1        67
# 2        42
# 3        51
# 4        53
# ...     ...
# 57577    94
# 57578    88
# 57579    96
# 57580    39
# 57581    65
#
# [57582 rows x 6 columns]

# %%
df = df.dropna()

# %%
df_drop = df.drop(0) #to drop row 0

# %%
df.drop(['Count', 'Rank'], axis=1)
# Out:
#        Year of Birth  Gender           Ethnicity Child's First Name
# 0               2011  FEMALE            HISPANIC          GERALDINE
# 1               2011  FEMALE            HISPANIC                GIA
# 2               2011  FEMALE            HISPANIC             GIANNA
# 3               2011  FEMALE            HISPANIC            GISELLE
# 4               2011  FEMALE            HISPANIC              GRACE
# ...              ...     ...                 ...                ...
# 57577           2014    MALE  WHITE NON HISPANIC             Yousef
# 57578           2014    MALE  WHITE NON HISPANIC            Youssef
# 57579           2014    MALE  WHITE NON HISPANIC              Yusuf
# 57580           2014    MALE  WHITE NON HISPANIC            Zachary
# 57581           2014    MALE  WHITE NON HISPANIC                Zev
#
# [57582 rows x 4 columns]

# %%
pivot_table = pd.pivot_table(df, index='Ethnicity', values='Count', aggfunc='sum')
pivot_table.head()
# Out:
#                              Count
# Ethnicity
# ASIAN AND PACI               60685
# ASIAN AND PACIFIC ISLANDER  202448
# BLACK NON HISP               59842
# BLACK NON HISPANIC          222928
# HISPANIC                    651299

# %%
pivot_table = pd.pivot_table(df, index=['Ethnicity','Gender'], values= 'Count' , aggfunc=['sum','count'])
pivot_table.head(20)
# Out:
#                                       sum count
#                                     Count Count
# Ethnicity                  Gender
# ASIAN AND PACI             FEMALE   25762  1066
#                            MALE     34923  1059
# ASIAN AND PACIFIC ISLANDER FEMALE   86812  3896
#                            MALE    115636  3934
# BLACK NON HISP             FEMALE   24908  1014
#                            MALE     34934  1079
# BLACK NON HISPANIC         FEMALE   94207  4118
#                            MALE    128721  4217
# HISPANIC                   FEMALE  275239  8676
#                            MALE    376060  8254
# WHITE NON HISP             FEMALE   72964  2196
#                            MALE     84215  1946
# WHITE NON HISPANIC         FEMALE  276851  8436
#                            MALE    322502  7691

# %%
grouped = df.groupby('Gender')
grouped.mean() # mean of each group
# Out:
# /tmp/ipykernel_165273/3653878763.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   grouped.mean() # mean of each group
#         Year of Birth      Count       Rank
# Gender
# FEMALE    2013.276410  29.138936  51.983471
# MALE      2013.290596  38.927999  62.369163

# %%
grouped = df.groupby(['Gender', 'Ethnicity'])
grouped.sum() #sum in each group
# Out:
# /tmp/ipykernel_165273/2257084475.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   grouped.sum() #sum in each group
#                                    Year of Birth   Count    Rank
# Gender Ethnicity
# FEMALE ASIAN AND PACI                    2144792   25762   35626
#        ASIAN AND PACIFIC ISLANDER        7845207   86812  116649
#        BLACK NON HISP                    2040168   24908   34546
#        BLACK NON HISPANIC                8291863   94207  130253
#        HISPANIC                         17466376  275239  515862
#        WHITE NON HISP                    4418352   72964  143189
#        WHITE NON HISPANIC               16987595  276851  552293
# MALE   ASIAN AND PACI                    2130708   34923   46613
#        ASIAN AND PACIFIC ISLANDER        7922012  115636  162587
#        BLACK NON HISP                    2170948   34934   47163
#        BLACK NON HISPANIC                8490919  128721  189222
#        HISPANIC                         16617186  376060  591637
#        WHITE NON HISP                    3915352   84215  137357
#        WHITE NON HISPANIC               15487404  322502  582984

# %%
df_transposed = df.transpose()

df_transposed.head()
# Out:
#                         0         1         2         3         4      \
# Year of Birth            2011      2011      2011      2011      2011
# Gender                 FEMALE    FEMALE    FEMALE    FEMALE    FEMALE
# Ethnicity            HISPANIC  HISPANIC  HISPANIC  HISPANIC  HISPANIC
# Child's First Name  GERALDINE       GIA    GIANNA   GISELLE     GRACE
# Count                      13        21        49        38        36
#
#                         5         6         7         8         9      ...  \
# Year of Birth            2011      2011      2011      2011      2011  ...
# Gender                 FEMALE    FEMALE    FEMALE    FEMALE    FEMALE  ...
# Ethnicity            HISPANIC  HISPANIC  HISPANIC  HISPANIC  HISPANIC  ...
# Child's First Name  GUADALUPE    HAILEY     HALEY    HANNAH    HAYLEE  ...
# Count                      26       126        14        17        17  ...
#
#                                  57572               57573  \
# Year of Birth                     2014                2014
# Gender                            MALE                MALE
# Ethnicity           WHITE NON HISPANIC  WHITE NON HISPANIC
# Child's First Name            Yitzchak            Yitzchok
# Count                               15                  66
#
#                                  57574               57575  \
# Year of Birth                     2014                2014
# Gender                            MALE                MALE
# Ethnicity           WHITE NON HISPANIC  WHITE NON HISPANIC
# Child's First Name                Yoel               Yosef
# Count                               12                 116
#
#                                  57576               57577  \
# Year of Birth                     2014                2014
# Gender                            MALE                MALE
# Ethnicity           WHITE NON HISPANIC  WHITE NON HISPANIC
# Child's First Name               Yossi              Yousef
# Count                               15                  18
#
#                                  57578               57579  \
# Year of Birth                     2014                2014
# Gender                            MALE                MALE
# Ethnicity           WHITE NON HISPANIC  WHITE NON HISPANIC
# Child's First Name             Youssef               Yusuf
# Count                               24                  16
#
#                                  57580               57581
# Year of Birth                     2014                2014
# Gender                            MALE                MALE
# Ethnicity           WHITE NON HISPANIC  WHITE NON HISPANIC
# Child's First Name             Zachary                 Zev
# Count                               90                  49
#
# [5 rows x 57582 columns]

# %%
# Create the first DataFrame
df1 = pd.DataFrame({'key': ['A', 'B', 'C', 'D'],
                   'value': [1, 2, 3, 4]})

# Create the second DataFrame
df2 = pd.DataFrame({'key': ['B', 'D', 'E', 'F'],
                   'value': [5, 6, 7, 8]})

# Merge the two DataFrames on the 'key' column
merged_df = df1.merge(df2, on='key')

# Print the merged DataFrame
print(merged_df)
# Out:
#   key  value_x  value_y
# 0   B        2        5
# 1   D        4        6

# %%
# Rename column 'Count' to 'count'
df_rename = df.rename(columns={'Count': 'count'})
df_rename.head()
# Out:
#    Year of Birth  Gender Ethnicity Child's First Name  count  Rank
# 0           2011  FEMALE  HISPANIC          GERALDINE     13    75
# 1           2011  FEMALE  HISPANIC                GIA     21    67
# 2           2011  FEMALE  HISPANIC             GIANNA     49    42
# 3           2011  FEMALE  HISPANIC            GISELLE     38    51
# 4           2011  FEMALE  HISPANIC              GRACE     36    53

# %%
df_rename = df.rename(columns={'Count': 'count', 'Rank':'rank'})
df_rename.head()
# Out:
#    Year of Birth  Gender Ethnicity Child's First Name  count  rank
# 0           2011  FEMALE  HISPANIC          GERALDINE     13    75
# 1           2011  FEMALE  HISPANIC                GIA     21    67
# 2           2011  FEMALE  HISPANIC             GIANNA     49    42
# 3           2011  FEMALE  HISPANIC            GISELLE     38    51
# 4           2011  FEMALE  HISPANIC              GRACE     36    53

# %%
df_rename = df.rename(index={0:'first',1:'second',2:'third'})
df_rename.head()
# Out:
#         Year of Birth  Gender Ethnicity Child's First Name  Count  Rank
# first            2011  FEMALE  HISPANIC          GERALDINE     13    75
# second           2011  FEMALE  HISPANIC                GIA     21    67
# third            2011  FEMALE  HISPANIC             GIANNA     49    42
# 3                2011  FEMALE  HISPANIC            GISELLE     38    51
# 4                2011  FEMALE  HISPANIC              GRACE     36    53

# %%
df.to_csv('../pandas/data.csv', sep='\t')
